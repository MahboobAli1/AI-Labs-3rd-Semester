# %% [markdown]
# ## Name: Mahboob Ali
# ## Sec: C
# ## Roll Num: 119
# ## Lab 6
# ## SAP ID: 5000000302

# %% [markdown]
# ## Task 1

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[30,56,34,45,33,39]
plt.plot(x,y,marker= '.',color='green', label= "Temperature")
plt.title( 'Six months Temperature ')
plt.xlabel('Months')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %% [markdown]
# ## Task 2

# %%
fruits= ["Apple","Banana","Grapes"]
quantity=[3,6,12]
plt.bar( fruits, quantity, color="red")
plt.title("Favourite Fruits")
plt.xlabel("Fruits")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# ## Task 3

# %%
Students=['Mahboob','Yasir','Bisma']
marks= [23,67,77]
explode=(0.1,0,0)
plt.title("Students result")
plt.pie(marks,labels=Students, explode=explode, autopct='%1.1f%%', shadow=True, startangle=90)
plt.show()

# %% [markdown]
# ## Treelib Exercises

# %% [markdown]
# ## Task 1

# %%
from treelib import Node, Tree


tree = Tree()


tree.create_node('Root', 'root')


tree.create_node('Left', 'left', parent='root')

tree.create_node('Right', 'right', parent='root')
tree.create_node('Left.Left', 'left.left', parent='left')
tree.create_node('Left.right', 'left.right', parent='left')
tree.create_node("Left.Left.Left", "left.left.left", parent="left.left")
tree.create_node('Right.Right', 'right.right', parent='right')
tree.create_node('Right.Left', 'right.left', parent='right')
tree.create_node("Right.Right.Right", "right.right.right", parent="right.right")

# Display the tree
tree.show()
# Out:
# Root
# ├── Left
# │   ├── Left.Left
# │   │   └── Left.Left.Left
# │   └── Left.right
# └── Right
#     ├── Right.Left
#     └── Right.Right
#         └── Right.Right.Right

# %% [markdown]
# ## Task 2

# %%
from treelib import Node, Tree


family = Tree()


family.create_node("Grandfather Ali", "grandfather")


family.create_node("Father Ahmed", "father", parent="grandfather")
family.create_node("Uncle Noor", "uncle", parent="grandfather")


family.create_node("Son Bilal", "son", parent="father")
family.create_node("Daughter Sara", "daughter", parent="father")


family.create_node("Cousin Ayesha (Youngest)", "youngest", parent="uncle")

print(" Family Tree:")
family.show()
# Out:
#  Family Tree:
# Grandfather Ali
# ├── Father Ahmed
# │   ├── Daughter Sara
# │   └── Son Bilal
# └── Uncle Noor
#     └── Cousin Ayesha (Youngest)

# %%
from treelib import Node, Tree


school = Tree()
school.create_node("Principal", "principal")


school.create_node("Teacher A", "teacher_a", parent="principal")
school.create_node("Teacher B", "teacher_b", parent="principal")


school.create_node("Student safii", "student_a1", parent="teacher_a")
school.create_node("Student Mahbbob", "student_a2", parent="teacher_a")
school.create_node("Student azad", "student_a3", parent="teacher_a")


school.create_node("Student yaqob", "student_b1", parent="teacher_b")
school.create_node("Student Yasir", "student_b2", parent="teacher_b")
school.create_node("Student Younus", "student_b3", parent="teacher_b")


print("School Hierarchy Tree:")
school.show()
# Out:
# School Hierarchy Tree:
# Principal
# ├── Teacher A
# │   ├── Student Mahbbob
# │   ├── Student azad
# │   └── Student safii
# └── Teacher B
#     ├── Student Yasir
#     ├── Student Younus
#     └── Student yaqob
