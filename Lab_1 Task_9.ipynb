# %%
##Mahboob Ali.AI Sec- C
##Roll. Num: 119
## Lab 1 Task 9

# %%
dis_km= int(input( " Enter distance in kilometers :"))
# Out:
#  Enter distance in kilometers : 10

# %%
print( " Distance in miles is : " ,dis_km/1.6)
# Out:
#  Distance in miles is :  6.25
