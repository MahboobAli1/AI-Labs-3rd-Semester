# %%
##Mahboob Ali.AI Sec- C
##Roll. Num: 119
## Lab 1 Task 7

# %%
sub1= int( input( " Enter marks of first subject : " ))
sub2= int( input( " Enter marks of second subject : " ))
sub3= int( input( " Enter marks of third subject : " ))
sub4= int( input( " Enter marks of  fourth subject : " ))
sub5= int( input( " Enter marks of fifth subject : " ))
# Out:
#  Enter marks of first subject :  22
#  Enter marks of second subject :  22
#  Enter marks of third subject :  22
#  Enter marks of  fourth subject :  22
#  Enter marks of fifth subject :  22

# %%
obt_marks= sub1+sub2+sub3+sub4+sub5

# %%
print ( " your total marks are :" , total
      ," average is : ",obt_mark/500*100 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 print ( " your total marks are :" , total
# ----> 2       ," average is : ",obt_mark/500*100 )
#
# NameError: name 'obt_mark' is not defined
