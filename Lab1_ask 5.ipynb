# %%
##Mahboob Ali.AI Sec- C
##Roll. Num: 119
## Lab 1 Task 5

# %%
num=int ( input( " Enter number to check" ))
# Out:
#  Enter number to check 5

# %%
if num%2==0:
    print ( " Number is even")
else: 
    print(" number is odd")
# Out:
#  number is odd
