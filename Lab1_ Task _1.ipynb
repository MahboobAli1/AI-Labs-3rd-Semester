# %%
##Mahboob Ali.AI Sec- C
##Roll. Num: 119
## Lab 1 Task 1
age= int(input( " Enter your age"))
# Out:
#  Enter your age 2

# %%
print( " your age in hours is:" ,(age*24*30*12) )
# Out:
#  your age in hours is: 17280
