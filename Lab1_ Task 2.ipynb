# %%
##Mahboob Ali.AI Sec- C
##Roll. Num: 119
## Lab 1 Task 2

# %%
radius= int( input( " Enter radius of circle "))
# Out:
#  Enter radius of circle  2

# %%
print ( " Area of circle is : " ,radius*radius*3.14)
# Out:
#  Area of circle is :  12.56
