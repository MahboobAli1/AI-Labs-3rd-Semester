# %%
##Mahboob Ali.AI Sec- C
##Roll. Num: 119
## Lab 1 Task 4

# %%
num= int( input( "Enter a number"))
# Out:
# Enter a number 2

# %%
square= num*num

# %%
cube= num*num*num

# %%
print( " number is :" ,num, " its square: " , square, " Its cube :" ,cube)
# Out:
#  number is : 2  its square:  4  Its cube : 8
