# %%
##Mahboob Ali.AI Sec- C
##Roll. Num: 119
## Lab 1 Task 3

# %%
cel= int( input( " Enter temp in celcius" ))
# Out:
#  Enter temp in celcius 2

# %%
 fare= (cel* 9/5)+ 32

# %%
print( " temp in farenheight is : ", fare)
