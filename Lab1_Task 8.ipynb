# %%
name= input( "Enter your name")
age = int (input(" Enter your age")) 
city= input( " enter your city")
print ( " name :" ,name ," age:" ,age, "city:",city)
# Out:
# Enter your name Mahboob_Ali
#  Enter your age 21
#  enter your city MirpurMathelo
#  name : Mahboob_Ali  age: 21 city: MirpurMathelo
